# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    ID SystemCodeNumber  Capacity   Latitude  Longitude  Occupancy VehicleType  \
# 0   0      BHMBCCMKT01       577  26.144536  91.736172         61         car
# 1   1      BHMBCCMKT01       577  26.144536  91.736172         64         car
# 2   2      BHMBCCMKT01       577  26.144536  91.736172         80         car
# 3   3      BHMBCCMKT01       577  26.144536  91.736172        107         car
# 4   4      BHMBCCMKT01       577  26.144536  91.736172        150        bike
#
#   TrafficConditionNearby  QueueLength  IsSpecialDay LastUpdatedDate  \
# 0                    low            1             0      04-10-2016
# 1                    low            1             0      04-10-2016
# 2                    low            2             0      04-10-2016
# 3                    low            2             0      04-10-2016
# 4                    low            2             0      04-10-2016
#
#   LastUpdatedTime
# 0        07:59:00
# 1        08:25:00
# 2        08:59:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18368 entries, 0 to 18367
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      18368 non-null  int64
#  1   SystemCodeNumber        18368 non-null  object
#  2   Capacity                18368 non-null  int64
#  3   Latitude                18368 non-null  float64
#  4   Longitude               18368 non-null  float64
#  5   Occupancy               18368 non-null  int64
#  6   VehicleType             18368 non-null  object
#  7   TrafficConditionNearby  18368 non-null  object
#  8   QueueLength             18368 non-null  int64
#  9   IsSpecialDay            18368 non-null  int64
#  10  LastUpdatedDate         18368 non-null  object
#  11  LastUpdatedTime         18368 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 1.7+ MB

# %%
df.isnull().sum()
# Out:
# ID                        0
# SystemCodeNumber          0
# Capacity                  0
# Latitude                  0
# Longitude                 0
# Occupancy                 0
# VehicleType               0
# TrafficConditionNearby    0
# QueueLength               0
# IsSpecialDay              0
# LastUpdatedDate           0
# LastUpdatedTime           0
# dtype: int64

# %%
df.describe()
# Out:
#                  ID      Capacity      Latitude     Longitude     Occupancy  \
# count  18368.000000  18368.000000  18368.000000  18368.000000  18368.000000
# mean    9183.500000   1605.214286     25.706547     90.751170    731.084059
# std     5302.529208   1131.153886      1.582749      3.536636    621.164982
# min        0.000000    387.000000     20.000035     78.000003      2.000000
# 25%     4591.750000    577.000000     26.140048     91.727995    322.000000
# 50%     9183.500000   1261.000000     26.147482     91.729511    568.000000
# 75%    13775.250000   2803.000000     26.147541     91.736172    976.000000
# max    18367.000000   3883.000000     26.150504     91.740994   3499.000000
#
#         QueueLength  IsSpecialDay
# count  18368.000000  18368.000000
# mean       4.587925      0.150915
# std        2.580062      0.357975
# min        0.000000      0.000000
# 25%        2.000000      0.000000
# 50%        4.000000      0.000000
# 75%        6.000000      0.000000
# ...

# %%
df['VehicleType'].value_counts()
# Out:
# VehicleType
# car      11166
# bike      3624
# truck     1809
# cycle     1769
# Name: count, dtype: int64

# %%
df[['Latitude','Longitude']].drop_duplicates()
# Out:
#         Latitude  Longitude
# 0      26.144536  91.736172
# 1312   26.144495  91.736205
# 2624   26.149020  91.739503
# 3936   20.000035  78.000003
# 5248   26.140014  91.731000
# 6560   26.140048  91.730972
# 7872   26.137958  91.740994
# 9184   26.147473  91.728049
# 10496  26.147541  91.727970
# 11808  26.147499  91.728005
# 13120  26.147491  91.727997
# 14432  26.147549  91.727995
# 15744  26.147500  91.727978
# 17056  26.150504  91.733531

# %%
df['IsSpecialDay'].value_counts()
# Out:
# IsSpecialDay
# 0    15596
# 1     2772
# Name: count, dtype: int64

# %%
#convert 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['LastUpdatedTime'])
df.head()
# Out:
# /tmp/ipython-input-25-2451487389.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['timestamp'] = pd.to_datetime(df['LastUpdatedTime'])
#    ID SystemCodeNumber  Capacity   Latitude  Longitude  Occupancy VehicleType  \
# 0   0      BHMBCCMKT01       577  26.144536  91.736172         61         car
# 1   1      BHMBCCMKT01       577  26.144536  91.736172         64         car
# 2   2      BHMBCCMKT01       577  26.144536  91.736172         80         car
# 3   3      BHMBCCMKT01       577  26.144536  91.736172        107         car
# 4   4      BHMBCCMKT01       577  26.144536  91.736172        150        bike
#
#   TrafficConditionNearby  QueueLength  IsSpecialDay LastUpdatedDate  \
# 0                    low            1             0      04-10-2016
# 1                    low            1             0      04-10-2016
# ...

# %%
#visualize occupancy trends

# %%
#filter for one lot
lot1_data = df[df['ID']==1]
#sort by time
lot1_data  = lot1_data.sort_values('timestamp')

plt.figure(figsize=(12,5))
plt.plot(lot1_data['timestamp'], lot1_data['Occupancy'], marker='+')
plt.title("Occupancy Trend for Lot 1")
plt.xlabel("Time")
plt.ylabel("Occupancy")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#occupancy for all lots by time of day

# %%
df['hour']=df['timestamp'].dt.hour

heat_map = df.groupby(['ID','hour'])['Occupancy'].mean().unstack()

# %%
# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(heat_map, cmap='YlOrRd', annot=True, fmt=".1f")
plt.title("Average Occupancy per Hour per Lot")
plt.xlabel("Hour of Day")
plt.ylabel("Lot ID")
plt.show()

# %%
#Phase 1 completed? yes! Phase 2 start
import pandas as pd

# Make sure timestamp is datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Sort by lot and time
df = df.sort_values(['ID', 'timestamp'])

# Parameters
BASE_PRICE = 10.0
ALPHA = 2.0
MIN_PRICE = 5.0
MAX_PRICE = 20.0

# Store last price per lot (starts with base price)
last_price = {}
baseline_prices = []

# Loop over rows
for _, row in df.iterrows():
    lot = row['ID']
    occ = row['Occupancy']
    cap = row['Capacity']

    prev_price = last_price.get(lot, BASE_PRICE)

    # Calculate new price
    ratio = occ / cap if cap > 0 else 0
    new_price = prev_price + ALPHA * ratio
    new_price = max(MIN_PRICE, min(MAX_PRICE, new_price))

    baseline_prices.append(new_price)
    last_price[lot] = new_price

# Add new column to DataFrame
df['baseline_price'] = baseline_prices

# Show first few rows
df[['timestamp', 'ID', 'Occupancy', 'Capacity', 'baseline_price']].head()
# Out:
#             timestamp  ID  Occupancy  Capacity  baseline_price
# 0 2025-07-07 07:59:00   0         61       577       10.211438
# 1 2025-07-07 08:25:00   1         64       577       10.221837
# 2 2025-07-07 08:59:00   2         80       577       10.277296
# 3 2025-07-07 09:32:00   3        107       577       10.370884
# 4 2025-07-07 09:59:00   4        150       577       10.519931

# %%
import matplotlib.pyplot as plt

# Plot for one lot only
lot1 = df[df['ID'] == 1]

plt.plot(lot1['timestamp'], lot1['baseline_price'], marker='o')
plt.title("Baseline Price over Time for Lot 1")
plt.xlabel("Time")
plt.ylabel("Price ($)")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    ID SystemCodeNumber  Capacity   Latitude  Longitude  Occupancy VehicleType  \
# 0   0      BHMBCCMKT01       577  26.144536  91.736172         61         car
# 1   1      BHMBCCMKT01       577  26.144536  91.736172         64         car
# 2   2      BHMBCCMKT01       577  26.144536  91.736172         80         car
# 3   3      BHMBCCMKT01       577  26.144536  91.736172        107         car
# 4   4      BHMBCCMKT01       577  26.144536  91.736172        150        bike
#
#   TrafficConditionNearby  QueueLength  IsSpecialDay LastUpdatedDate  \
# 0                    low            1             0      04-10-2016
# 1                    low            1             0      04-10-2016
# 2                    low            2             0      04-10-2016
# 3                    low            2             0      04-10-2016
# 4                    low            2             0      04-10-2016
#
#   LastUpdatedTime           timestamp  hour  baseline_price
# ...

# %%
BASE_PRICE = 10.0
MIN_PRICE = 5.0
MAX_PRICE = 20.0

# Weights for demand components
ALPHA = 1.0      # Occupancy weight
BETA = 0.5       # Queue weight
GAMMA = 0.3      # Traffic penalty
DELTA = 2.0      # Special day bonus
EPSILON = 1.0    # Vehicle type impact
LAMBDA = 0.5     # How much demand affects price

# %%
 vehicle_weights = {
    'car': 1.0,
    'bike': 0.5,
    'truck': 1.5
}
traffic_mapping = {'low': 1, 'average': 2, 'high': 3}
df['TrafficScore'] = df['TrafficConditionNearby'].map(traffic_mapping)

# %%
df['VehicleType'].value_counts()['cycle']
# Out:
# np.int64(1769)

# %%
df = df[df['VehicleType'] != 'cycle']

# %%
# Replace vehicle types with weights
df['VehicleWeight'] = df['VehicleType'].map(vehicle_weights)

# Calculate raw demand
df['RawDemand'] = (
    ALPHA * (df['Occupancy'] / df['Capacity'].replace(0, 1)) +  # Avoid divide-by-zero
    BETA * df['QueueLength'] -
    GAMMA * df['TrafficScore'] +
    DELTA * df['IsSpecialDay'] +
    EPSILON * df['VehicleWeight']
)

# %%
min_demand = df['RawDemand'].min()
max_demand = df['RawDemand'].max()

# Avoid division by 0
if max_demand - min_demand == 0:
    df['NormDemand'] = 0
else:
    df['NormDemand'] = (df['RawDemand'] - min_demand) / (max_demand - min_demand)

# %%
df['demand_price'] = BASE_PRICE * (1 + LAMBDA * df['NormDemand'])

# Clamp prices
df['demand_price'] = df['demand_price'].clip(lower=MIN_PRICE, upper=MAX_PRICE)

# %%
df[['timestamp', 'ID', 'Occupancy', 'QueueLength', 'TrafficScore', 'IsSpecialDay', 'VehicleWeight', 'demand_price']].head()
# Out:
#             timestamp  ID  Occupancy  QueueLength  TrafficScore  IsSpecialDay  \
# 0 2025-07-07 07:59:00   0         61            1             1             0
# 1 2025-07-07 08:25:00   1         64            1             1             0
# 2 2025-07-07 08:59:00   2         80            2             1             0
# 3 2025-07-07 09:32:00   3        107            2             1             0
# 4 2025-07-07 09:59:00   4        150            2             1             0
#
#    VehicleWeight  demand_price
# 0            1.0     10.529047
# 1            1.0     10.531578
# 2            1.0     10.788507
# 3            1.0     10.811289
# 4            0.5     10.604142

# %%
# Phase 2 completed ? start 3
# Compute average demand price per location (excluding self)
avg_prices = df.groupby('ID')['demand_price'].transform('mean')

# Apply competitive adjustment
def adjust_price(row):
    base_price = row['demand_price']
    location_avg = avg_prices[row.name]

    # Adjustment rules
    if base_price < location_avg:
        # Undervalued → increase slightly
        return min(base_price + 1.0, 20)
    elif base_price > location_avg:
        # Overpriced → reduce slightly
        return max(base_price - 1.0, 5)
    else:
        return base_price

df['location_id'] = np.random.choice([101, 102, 103], size=len(df))

avg_prices = df.groupby('location_id')['demand_price'].transform('mean')


#df['competitive_price'] = df.apply(adjust_price, axis=1
df['competitive_price'] = df['demand_price'] + 0.5 * (avg_prices - df['demand_price'])
df['competitive_price'] = df['competitive_price'].clip(5, 20)

df['avg_price'] = avg_prices
df['price_diff'] = df['avg_price'] - df['demand_price']
df[['ID', 'location_id', 'demand_price', 'avg_price', 'price_diff', 'competitive_price']].head(10)
# Out:
#     ID  location_id  demand_price  avg_price  price_diff  competitive_price
# 0    0          103     10.529047  11.608697    1.079650          11.068872
# 1    1          102     10.531578  11.605172    1.073594          11.068375
# 2    2          101     10.788507  11.596110    0.807603          11.192308
# 3    3          101     10.811289  11.596110    0.784821          11.203699
# 4    4          103     10.604142  11.608697    1.004554          11.106420
# 5    5          101     11.113782  11.596110    0.482327          11.354946
# 6    6          103     11.830822  11.608697   -0.222125          11.719759
# 7    7          102     11.513647  11.605172    0.091525          11.559409
# 9    9          101     11.870479  11.596110   -0.274369          11.733294
# 10  10          102     11.873010  11.605172   -0.267839          11.739091

# %%
# !pip install pathway

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from datetime import datetime
import pathway as pw
import bokeh.plotting
import panel as pn
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1f150afe-efe6-446e-a4c3-7402d10f0547'>
#   <div id="ad52e581-9c9e-4d8c-8f10-1ff4fece4814" data-root-id="1f150afe-efe6-446e-a4c3-7402d10f0547" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
df = pd.read_csv('dataset.csv')
df

# You can find the sample dataset here: https://drive.google.com/file/d/1D479FLjp9aO3Mg8g6Lpj9oRViWacurA6/view?usp=sharing
# Out:
#           ID SystemCodeNumber  Capacity   Latitude  Longitude  Occupancy  \
# 0          0      BHMBCCMKT01       577  26.144536  91.736172         61
# 1          1      BHMBCCMKT01       577  26.144536  91.736172         64
# 2          2      BHMBCCMKT01       577  26.144536  91.736172         80
# 3          3      BHMBCCMKT01       577  26.144536  91.736172        107
# 4          4      BHMBCCMKT01       577  26.144536  91.736172        150
# ...      ...              ...       ...        ...        ...        ...
# 18363  18363         Shopping      1920  26.150504  91.733531       1517
# 18364  18364         Shopping      1920  26.150504  91.733531       1487
# 18365  18365         Shopping      1920  26.150504  91.733531       1432
# 18366  18366         Shopping      1920  26.150504  91.733531       1321
# 18367  18367         Shopping      1920  26.150504  91.733531       1180
#
#       VehicleType TrafficConditionNearby  QueueLength  IsSpecialDay  \
# ...

# %%
# Combine the 'LastUpdatedDate' and 'LastUpdatedTime' columns into a single datetime column
df['Timestamp'] = pd.to_datetime(df['LastUpdatedDate'] + ' ' + df['LastUpdatedTime'],
                                  format='%d-%m-%Y %H:%M:%S')

# Sort the DataFrame by the new 'Timestamp' column and reset the index
df = df.sort_values('Timestamp').reset_index(drop=True)

# %%
# Save the selected columns to a CSV file for streaming or downstream processing
df[["Timestamp", "Occupancy", "Capacity"]].to_csv("parking_stream.csv", index=False)

# Note: Only three features are used here for simplicity.
# Participants are expected to incorporate additional relevant features in their models.

# %%
# Define the schema for the streaming data using Pathway
# This schema specifies the expected structure of each data row in the stream

class ParkingSchema(pw.Schema):
    Timestamp: str   # Timestamp of the observation (should ideally be in ISO format)
    Occupancy: int   # Number of occupied parking spots
    Capacity: int    # Total parking capacity at the location

# %%
# Load the data as a simulated stream using Pathway's replay_csv function
# This replays the CSV data at a controlled input rate to mimic real-time streaming
# input_rate=1000 means approximately 1000 rows per second will be ingested into the stream.

data = pw.demo.replay_csv("parking_stream.csv", schema=ParkingSchema, input_rate=1000)

# %%
# Define the datetime format to parse the 'Timestamp' column
fmt = "%Y-%m-%d %H:%M:%S"

# Add new columns to the data stream:
# - 't' contains the parsed full datetime
# - 'day' extracts the date part and resets the time to midnight (useful for day-level aggregations)
data_with_time = data.with_columns(
    t = data.Timestamp.dt.strptime(fmt),
    day = data.Timestamp.dt.strptime(fmt).dt.strftime("%Y-%m-%dT00:00:00")
)

# %%
# Define a daily tumbling window over the data stream using Pathway
# This block performs temporal aggregation and computes a dynamic price for each day
import datetime

delta_window = (
    data_with_time.windowby(
        pw.this.t,               # Use the parsed timestamp column
        instance=pw.this.day,    # One window per 'day'
        window=pw.temporal.tumbling(datetime.timedelta(days=1)),  # Daily tumbling window
        behavior=pw.temporal.exactly_once_behavior()  # Ensures no double processing
    )
    .reduce(
        t=pw.this._pw_window_end,                        # Assign the end timestamp of each window
        occ_max=pw.reducers.max(pw.this.Occupancy),      # Highest occupancy observed in the window
        occ_min=pw.reducers.min(pw.this.Occupancy),      # Lowest occupancy observed in the window
        cap=pw.reducers.max(pw.this.Capacity),           # Maximum capacity observed (typically constant per spot)
    )
    .with_columns(
        # Compute the price using a simple dynamic pricing formula:
        #
        # Pricing Formula:
        #     price = base_price + demand_fluctuation
        #     where:
        #         base_price = 10 (fixed minimum price)
        #         demand_fluctuation = (occ_max - occ_min) / cap
        #
        # Intuition:
        # - The greater the difference between peak and low occupancy in a day,
        #   the more volatile the demand is, indicating potential scarcity.
        # - Dividing by capacity normalizes the fluctuation (to stay in [0,1] range).
        # - This fluctuation is added to the base price of 10 to set the final price.
        # - Example: If occ_max = 90, occ_min = 30, cap = 100
        #            => price = 10 + (90 - 30)/100 = 10 + 0.6 = 10.6

        price=10 + (pw.this.occ_max - pw.this.occ_min) / pw.this.cap
    )
)

# %%
# Activate the Panel extension to enable interactive visualizations
pn.extension()

# Define a custom Bokeh plotting function that takes a data source (from Pathway) and returns a figure
def price_plotter(source):
    # Create a Bokeh figure with datetime x-axis
    fig = bokeh.plotting.figure(
        height=400,
        width=800,
        title="Pathway: Daily Parking Price",
        x_axis_type="datetime",  # Ensure time-based data is properly formatted on the x-axis
    )
    # Plot a line graph showing how the price evolves over time
    fig.line("t", "price", source=source, line_width=2, color="navy")

    # Overlay red circles at each data point for better visibility
    fig.circle("t", "price", source=source, size=6, color="red")

    return fig

# Use Pathway's built-in .plot() method to bind the data stream (delta_window) to the Bokeh plot
# - 'price_plotter' is the rendering function
# - 'sorting_col="t"' ensures the data is plotted in time order
viz = delta_window.plot(price_plotter, sorting_col="t")

# Create a Panel layout and make it servable as a web app
# This line enables the interactive plot to be displayed when the app is served
pn.Column(viz).servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='9ba6f831-4e95-4ef0-9d1a-dddcc980de65'>
#   <div id="cab7b02f-9251-4973-a48c-ad5b9dd4d2ff" data-root-id="9ba6f831-4e95-4ef0-9d1a-dddcc980de65" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Start the Pathway pipeline execution in the background
# - This triggers the real-time data stream processing defined above
# - %%capture --no-display suppresses output in the notebook interface

# %%capture --no-display
pw.run()
# Out:
# Output()
# WARNING:pathway_engine.connectors.monitoring:PythonReader: Closing the data source
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from IPython.display import Image

# %%
Image(filename="C:/Users/Yashit/OneDrive/Pictures/Screenshots/Screenshot 2025-07-07 235458.png")

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
#Visualization using Bokesh
from bokeh.plotting import figure, show, output_notebook
from bokeh.palettes import Category10
output_notebook()

p = figure(x_axis_type='datetime',
           title="Real-Time Pricing Comparison",
           width=800, height=400)

colors = Category10[10]
lot_ids = df['ID'].unique()[:2]  # pick 2 lots to avoid clutter

for i, lot_id in enumerate(lot_ids):
    # Filter the DataFrame for this lot
    temp = df[df['ID'] == lot_id]

    # Plot demand price
    p.line(temp['timestamp'], temp['demand_price'],
           line_color=colors[i], line_width=2,
           legend_label=f"Lot {lot_id} - Demand Price")

    # Plot competitive price
    p.line(temp['timestamp'], temp['competitive_price'],
           line_color=colors[i], line_dash='dashed', line_width=2,
           legend_label=f"Lot {lot_id} - Competitive Price")

# Add labels and show
p.legend.location = "top_left"
p.xaxis.axis_label = "Time"
p.yaxis.axis_label = "Price"
p.title.text_font_size = '14pt'

show(p)
# Out:
#   <div id="e09381e0-c176-4425-b076-29c23baee8a1" data-root-id="5766b00c-d0c6-4d64-a8d4-faf70f23ea7c" style="display: contents;"></div>

# %%
print(df[['ID', 'timestamp', 'demand_price', 'competitive_price']].head())
# Out:
#         ID           timestamp  demand_price  competitive_price
# 7370  7370 2025-07-07 07:41:00     11.910544          11.757858
# 7514  7514 2025-07-07 07:42:00     10.671316          11.138244
# 7515  7515 2025-07-07 07:42:00     11.158173          11.383435
# 7516  7516 2025-07-07 07:42:00     10.914744          11.261721
# 7517  7517 2025-07-07 07:42:00     10.914744          11.261721

# %%
 print(df['ID'].value_counts().head())
# Out:
# ID
# 1923    1
# 7370    1
# 7514    1
# 7515    1
# 7516    1
# Name: count, dtype: int64

# %%
 print(df[['ID', 'timestamp']].groupby('ID').agg(['min', 'max']))
# Out:
#                 timestamp
#                       min                 max
# ID
# 0     2025-07-07 07:59:00 2025-07-07 07:59:00
# 1     2025-07-07 08:25:00 2025-07-07 08:25:00
# 2     2025-07-07 08:59:00 2025-07-07 08:59:00
# 3     2025-07-07 09:32:00 2025-07-07 09:32:00
# 4     2025-07-07 09:59:00 2025-07-07 09:59:00
# ...                   ...                 ...
# 18362 2025-07-07 14:03:00 2025-07-07 14:03:00
# 18363 2025-07-07 14:30:00 2025-07-07 14:30:00
# 18364 2025-07-07 15:03:00 2025-07-07 15:03:00
# 18366 2025-07-07 16:03:00 2025-07-07 16:03:00
# 18367 2025-07-07 16:30:00 2025-07-07 16:30:00
#
# [16599 rows x 2 columns]

# %%
df[['demand_price', 'competitive_price']].describe()
# Out:
#        demand_price  competitive_price
# count  16599.000000       16599.000000
# mean      11.603305          11.603305
# std        0.727512           0.363785
# min       10.000000          10.802586
# 25%       11.043349          11.323296
# 50%       11.472460          11.538059
# 75%       12.059287          11.831149
# max       15.000000          13.298055

# %%
df['demand_price'] += np.random.normal(0, 0.1, size=len(df))
df['competitive_price'] += np.random.normal(0, 0.1, size=len(df))

# %%
lot_ids = df['ID'].unique()[:2]

# %%
lot_id = df['ID'].unique()[0]
df[df['ID'] == lot_id][['timestamp', 'demand_price', 'competitive_price']]
# Out:
#                timestamp  demand_price  competitive_price
# 7370 2025-07-07 07:41:00      12.06469          11.750564

# %%
p = figure(x_axis_type='datetime', title="Full Price Plot", width=800, height=400)

p.line(df['timestamp'], df['demand_price'], color='blue', legend_label="Demand Price")
p.line(df['timestamp'], df['competitive_price'], color='red', line_dash='dashed', legend_label="Competitive Price")

p.legend.location = "top_left"
p.xaxis.axis_label = "Time"
p.yaxis.axis_label = "Price"
p.title.text_font_size = '14pt'

show(p)
# Out:
#   <div id="b039877d-ff9a-4975-b4b0-c3714b07c13e" data-root-id="06a28aab-80cb-4ab4-b5d5-ae7df62517a8" style="display: contents;"></div>

# %%
Image(filename="C:/Users/Yashit/OneDrive\Pictures\Screenshots\Screenshot 2025-07-07 235510.png")
